# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Resources/amazon.csv")
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460         NaN                                                NaN
# 1461         NaN                                                NaN
# 1462         NaN                                                NaN
# 1463         NaN                                                NaN
# 1464         NaN                                                NaN
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3     Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4     Computers&Accessories|Accessories&Peripherals|...             ₹154
# ...                                                 ...              ...
# 1460                                                NaN              NaN
# 1461                                                NaN              NaN
# 1462                                                NaN              NaN
# 1463                                                NaN              NaN
# 1464                                                NaN              NaN
#
#      actual_price discount_percentage  rating rating_count
# 0          ₹1,099                 64%     4.2       24,269
# 1            ₹349                 43%     4.0       43,994
# 2          ₹1,899                 90%     3.9        7,928
# 3            ₹699                 53%     4.2       94,363
# 4            ₹399                 61%     4.2       16,905
# ...           ...                 ...     ...          ...
# 1460          NaN                 NaN     NaN          NaN
# 1461          NaN                 NaN     NaN          NaN
# 1462          NaN                 NaN     NaN          NaN
# 1463          NaN                 NaN     NaN          NaN
# 1464          NaN                 NaN     NaN          NaN
#
# [1465 rows x 8 columns]

# %%
df = df.dropna()
df
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 994  B08WKCTFF3  ZEBRONICS Aluminium Alloy Laptop Stand, Compat...
# 995  B08498D67S  HP K500F Backlit Membrane Wired Gaming Keyboar...
# 996  B00C3GBCIS  GIZGA Club-laptop Neoprene Reversible for 15.6...
# 997  B00URH5E34  Inventis 5V 1.2W Portable Flexible USB LED Lig...
# 998  B00EYW1U68  TP-Link TL-WA855RE 300 Mbps Wi-Fi Range Extend...
#
#                                               category discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3    Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4    Computers&Accessories|Accessories&Peripherals|...             ₹154
# ..                                                 ...              ...
# 994  Computers&Accessories|Accessories&Peripherals|...             ₹899
# 995  Computers&Accessories|Accessories&Peripherals|...           ₹1,149
# 996  Computers&Accessories|Accessories&Peripherals|...             ₹249
# 997  Computers&Accessories|Accessories&Peripherals|...              ₹39
# 998  Computers&Accessories|NetworkingDevices|Repeat...           ₹1,599
#
#     actual_price discount_percentage  rating rating_count
# 0         ₹1,099                 64%     4.2       24,269
# 1           ₹349                 43%     4.0       43,994
# 2         ₹1,899                 90%     3.9        7,928
# 3           ₹699                 53%     4.2       94,363
# 4           ₹399                 61%     4.2       16,905
# ..           ...                 ...     ...          ...
# 994       ₹1,999                 55%     4.4        1,667
# 995       ₹1,800                 36%     4.3        4,723
# 996         ₹499                 50%     4.2       22,860
# 997          ₹39                  0%     3.6       13,572
# 998       ₹3,599                 56%     4.2       16,182
#
# [997 rows x 8 columns]

# %%
df.loc[:, 'discounted_price'] = df['discounted_price'].replace(',', '', regex=True)
df.loc[:, 'discounted_price'] = df['discounted_price'].replace('₹', '', regex=True)

# %%
df
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 994  B08WKCTFF3  ZEBRONICS Aluminium Alloy Laptop Stand, Compat...
# 995  B08498D67S  HP K500F Backlit Membrane Wired Gaming Keyboar...
# 996  B00C3GBCIS  GIZGA Club-laptop Neoprene Reversible for 15.6...
# 997  B00URH5E34  Inventis 5V 1.2W Portable Flexible USB LED Lig...
# 998  B00EYW1U68  TP-Link TL-WA855RE 300 Mbps Wi-Fi Range Extend...
#
#                                               category discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...              399
# 1    Computers&Accessories|Accessories&Peripherals|...              199
# 2    Computers&Accessories|Accessories&Peripherals|...              199
# 3    Computers&Accessories|Accessories&Peripherals|...              329
# 4    Computers&Accessories|Accessories&Peripherals|...              154
# ..                                                 ...              ...
# 994  Computers&Accessories|Accessories&Peripherals|...              899
# 995  Computers&Accessories|Accessories&Peripherals|...             1149
# 996  Computers&Accessories|Accessories&Peripherals|...              249
# 997  Computers&Accessories|Accessories&Peripherals|...               39
# 998  Computers&Accessories|NetworkingDevices|Repeat...             1599
#
#     actual_price discount_percentage  rating rating_count
# 0         ₹1,099                 64%     4.2       24,269
# 1           ₹349                 43%     4.0       43,994
# 2         ₹1,899                 90%     3.9        7,928
# 3           ₹699                 53%     4.2       94,363
# 4           ₹399                 61%     4.2       16,905
# ..           ...                 ...     ...          ...
# 994       ₹1,999                 55%     4.4        1,667
# 995       ₹1,800                 36%     4.3        4,723
# 996         ₹499                 50%     4.2       22,860
# 997          ₹39                  0%     3.6       13,572
# 998       ₹3,599                 56%     4.2       16,182
#
# [997 rows x 8 columns]

# %%
df.loc[:, 'actual_price'] = df['actual_price'].replace(',', '', regex=True)
df.loc[:, 'actual_price'] = df['actual_price'].replace('₹', '', regex=True)

# %%
df["actual_price"] = df["actual_price"].astype(float)
# Out:
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\2712852494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["actual_price"] = df["actual_price"].astype(float)

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price        object
# actual_price           float64
# discount_percentage     object
# rating                 float64
# rating_count            object
# dtype: object

# %%
df["discounted_price"] = df["discounted_price"].astype(float)
# Out:
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\1888632260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["discounted_price"] = df["discounted_price"].astype(float)

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage     object
# rating                 float64
# rating_count            object
# dtype: object

# %%
df
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 994  B08WKCTFF3  ZEBRONICS Aluminium Alloy Laptop Stand, Compat...
# 995  B08498D67S  HP K500F Backlit Membrane Wired Gaming Keyboar...
# 996  B00C3GBCIS  GIZGA Club-laptop Neoprene Reversible for 15.6...
# 997  B00URH5E34  Inventis 5V 1.2W Portable Flexible USB LED Lig...
# 998  B00EYW1U68  TP-Link TL-WA855RE 300 Mbps Wi-Fi Range Extend...
#
#                                               category  discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             399.0
# 1    Computers&Accessories|Accessories&Peripherals|...             199.0
# 2    Computers&Accessories|Accessories&Peripherals|...             199.0
# 3    Computers&Accessories|Accessories&Peripherals|...             329.0
# 4    Computers&Accessories|Accessories&Peripherals|...             154.0
# ..                                                 ...               ...
# 994  Computers&Accessories|Accessories&Peripherals|...             899.0
# 995  Computers&Accessories|Accessories&Peripherals|...            1149.0
# 996  Computers&Accessories|Accessories&Peripherals|...             249.0
# 997  Computers&Accessories|Accessories&Peripherals|...              39.0
# 998  Computers&Accessories|NetworkingDevices|Repeat...            1599.0
#
#      actual_price discount_percentage  rating rating_count
# 0          1099.0                 64%     4.2       24,269
# 1           349.0                 43%     4.0       43,994
# 2          1899.0                 90%     3.9        7,928
# 3           699.0                 53%     4.2       94,363
# 4           399.0                 61%     4.2       16,905
# ..            ...                 ...     ...          ...
# 994        1999.0                 55%     4.4        1,667
# 995        1800.0                 36%     4.3        4,723
# 996         499.0                 50%     4.2       22,860
# 997          39.0                  0%     3.6       13,572
# 998        3599.0                 56%     4.2       16,182
#
# [997 rows x 8 columns]

# %%
df['discount_percentage'] = df['discount_percentage'].astype(str)
df['discount_percentage'] = df['discount_percentage'].str.replace('%', '')
df['discount_percentage'] = df['discount_percentage'].astype(float)
df['discount_percentage'] = df['discount_percentage'] / 100
# Out:
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\383771125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'].astype(str)
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\383771125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'].str.replace('%', '')
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\383771125.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'].astype(float)
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\383771125.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'] / 100

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype(float)
df
# Out:
# C:\Users\NIMISH\AppData\Local\Temp\ipykernel_15384\969274322.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating_count'] = df['rating_count'].str.replace(',', '').astype(float)
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 994  B08WKCTFF3  ZEBRONICS Aluminium Alloy Laptop Stand, Compat...
# 995  B08498D67S  HP K500F Backlit Membrane Wired Gaming Keyboar...
# 996  B00C3GBCIS  GIZGA Club-laptop Neoprene Reversible for 15.6...
# 997  B00URH5E34  Inventis 5V 1.2W Portable Flexible USB LED Lig...
# 998  B00EYW1U68  TP-Link TL-WA855RE 300 Mbps Wi-Fi Range Extend...
#
#                                               category  discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             399.0
# 1    Computers&Accessories|Accessories&Peripherals|...             199.0
# 2    Computers&Accessories|Accessories&Peripherals|...             199.0
# 3    Computers&Accessories|Accessories&Peripherals|...             329.0
# 4    Computers&Accessories|Accessories&Peripherals|...             154.0
# ..                                                 ...               ...
# 994  Computers&Accessories|Accessories&Peripherals|...             899.0
# 995  Computers&Accessories|Accessories&Peripherals|...            1149.0
# 996  Computers&Accessories|Accessories&Peripherals|...             249.0
# 997  Computers&Accessories|Accessories&Peripherals|...              39.0
# 998  Computers&Accessories|NetworkingDevices|Repeat...            1599.0
#
#      actual_price  discount_percentage  rating  rating_count
# 0          1099.0                 0.64     4.2       24269.0
# 1           349.0                 0.43     4.0       43994.0
# 2          1899.0                 0.90     3.9        7928.0
# 3           699.0                 0.53     4.2       94363.0
# 4           399.0                 0.61     4.2       16905.0
# ..            ...                  ...     ...           ...
# 994        1999.0                 0.55     4.4        1667.0
# 995        1800.0                 0.36     4.3        4723.0
# 996         499.0                 0.50     4.2       22860.0
# 997          39.0                 0.00     3.6       13572.0
# 998        3599.0                 0.56     4.2       16182.0
#
# [997 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

features = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']
target_variable = 'discounted_price'

x = df[features].drop(target_variable, axis=1)
y = df[target_variable]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

model = LinearRegression()
fit_model = model.fit(x_train, y_train)

predictions = model.predict(x_test)

mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r_squared = r2_score(y_test, predictions)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r_squared}")
# Out:
# Mean Absolute Error: 1020.2546210803165
# Mean Squared Error: 3821890.8884062935
# R-squared: 0.9483821496864399

# %%
import matplotlib.pyplot as plt
# Convert y_test and predictions to NumPy arrays
y_test_array = y_test.values.astype(float)
predictions_array = predictions.astype(float)

# Plotting the actual vs. predicted values as distinct points
plt.figure(figsize=(8, 6))

# Scatter plot of actual vs. predicted values
plt.scatter(y_test_array, predictions_array, alpha=0.5, label='Actual vs. Predicted', c='blue')

# Plot the diagonal line (best-fit line)
y_min = min(np.min(y_test_array), np.min(predictions_array))
y_max = max(np.max(y_test_array), np.max(predictions_array))
plt.plot([y_min, y_max], [y_min, y_max], color='red', label='Best-fit line')

plt.title('Actual vs. Predicted Values')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.legend()
plt.grid(True)
plt.show()

# %%
fit_model.score(x_test,y_test)
# Out:
# 0.9483821496864399

# %%
alpha_value = 1.0
ridge = Ridge(alpha = alpha_value)
ridge.fit(x_train_scaled, y_train)
y_pred = ridge.predict(x_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r_squared}")
# Out:
# Mean Absolute Error: 1020.4574685949539
# Mean Squared Error: 3821758.44274734
# R-squared: 0.9483839384764389

# %%
import matplotlib.pyplot as plt
# Convert y_test and predictions to NumPy arrays
y_test_array = y_test.values.astype(float)
predictions_array = y_pred.astype(float)

# Plotting the actual vs. predicted values as distinct points
plt.figure(figsize=(8, 6))

# Scatter plot of actual vs. predicted values
plt.scatter(y_test_array, predictions_array, alpha=0.5, label='Actual vs. Predicted', c='blue')

# Plot the diagonal line (best-fit line)
y_min = min(np.min(y_test_array), np.min(predictions_array))
y_max = max(np.max(y_test_array), np.max(predictions_array))
plt.plot([y_min, y_max], [y_min, y_max], color='red', label='Best-fit line')

plt.title('Ridge Actual vs. Predicted Values')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.legend()
plt.grid(True)
plt.show()
